# %%
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib as mpl
import os
import matplotlib.pyplot as plt
import scipy.stats as si
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
import datetime as dt  # optional

# %%
data = yf.download("GBPUSD=X", start="2016-1-1", end="2022-1-1")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.describe()
# Out:
#               Open         High          Low        Close    Adj Close  Volume
# count  1563.000000  1563.000000  1563.000000  1563.000000  1563.000000  1563.0
# mean      1.319499     1.324309     1.314462     1.319526     1.319526     0.0
# std       0.062020     0.061984     0.061856     0.062004     0.062004     0.0
# min       1.149637     1.171166     1.147684     1.149439     1.149439     0.0
# 25%       1.275901     1.281271     1.272467     1.275974     1.275974     0.0
# 50%       1.310925     1.315288     1.306302     1.310839     1.310839     0.0
# 75%       1.366764     1.369825     1.361285     1.366867     1.366867     0.0
# max       1.479202     1.494701     1.473839     1.478940     1.478940     0.0

# %%
data.head()
# Out:
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2016-01-01  1.473839  1.473839  1.473839  1.473839   1.473839       0
# 2016-01-04  1.473991  1.481701  1.469141  1.473709   1.473709       0
# 2016-01-05  1.471454  1.472971  1.464129  1.471410   1.471410       0
# 2016-01-06  1.467696  1.467998  1.460494  1.467394   1.467394       0
# 2016-01-07  1.462929  1.464343  1.453488  1.462994   1.462994       0

# %%
data.tail()
# Out:
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2021-12-27  1.340520  1.344070  1.339226  1.340430   1.340430       0
# 2021-12-28  1.344447  1.346257  1.341832  1.344267   1.344267       0
# 2021-12-29  1.343400  1.349928  1.340914  1.343328   1.343328       0
# 2021-12-30  1.349764  1.352155  1.345533  1.349879   1.349879       0
# 2021-12-31  1.349892  1.354848  1.346747  1.349837   1.349837       0

# %%
data[['Adj Close']].head()
# Out:
#             Adj Close
# Date
# 2016-01-01   1.473839
# 2016-01-04   1.473709
# 2016-01-05   1.471410
# 2016-01-06   1.467394
# 2016-01-07   1.462994

# %%
my_data =  data[['Adj Close']]
data.describe()                         #setting up the dataframe to describe the data
# Out:
#               Open         High          Low        Close    Adj Close  Volume
# count  1563.000000  1563.000000  1563.000000  1563.000000  1563.000000  1563.0
# mean      1.319499     1.324309     1.314462     1.319526     1.319526     0.0
# std       0.062020     0.061984     0.061856     0.062004     0.062004     0.0
# min       1.149637     1.171166     1.147684     1.149439     1.149439     0.0
# 25%       1.275901     1.281271     1.272467     1.275974     1.275974     0.0
# 50%       1.310925     1.315288     1.306302     1.310839     1.310839     0.0
# 75%       1.366764     1.369825     1.361285     1.366867     1.366867     0.0
# max       1.479202     1.494701     1.473839     1.478940     1.478940     0.0

# %%
my_data.head()
# Out:
#             Adj Close
# Date
# 2016-01-01   1.473839
# 2016-01-04   1.473709
# 2016-01-05   1.471410
# 2016-01-06   1.467394
# 2016-01-07   1.462994

# %%
my_data.tail()
# Out:
#             Adj Close
# Date
# 2021-12-27   1.340430
# 2021-12-28   1.344267
# 2021-12-29   1.343328
# 2021-12-30   1.349879
# 2021-12-31   1.349837

# %%
my_data[my_data["Adj Close"] == my_data["Adj Close"].min()]
# Out:
#             Adj Close
# Date
# 2020-03-20   1.149439

# %%
my_data[my_data["Adj Close"] == my_data["Adj Close"].max()]
# Out:
#             Adj Close
# Date
# 2016-06-23    1.47894

# %%
plt.figure(figsize=[3, 1.5], facecolor="w", dpi=500)
sns.set_style(style="darkgrid")
sns.lineplot(data.index, data["Adj Close"])
#sns.lineplot(data.index, data["Adj Close"].rolling(window=20).mean())
plt.legend(["CURRENCY PRICE","Moving Average"])
plt.title("GBP/USD")
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'GBP/USD')

# %%
pip install arch
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
import matplotlib.pyplot as plt
import datetime as dt  # optional


st = dt.datetime(2016, 1, 1) # setting the date. Optional line.
en = dt.datetime(2022, 1, 1) # setting the date. Optional line.





returns = 100 * my_data.pct_change().dropna() # generating return series
ax = returns.plot() # ploting the data

#xlim = ax.set_xlim(returns.index.min(), returns.index.max())

# Estimating a GARCH and ARCH models
from arch import arch_model

model1 = arch_model(returns, p=1,o=0,q=0)
out1=model1.fit()
print(out1.summary())

model2 = arch_model(returns, p=1,o=0,q=1)
out2=model2.fit()
print(out2.summary())

fig1 = out1.plot(annualize="D") #generating volatility graphs

fig2 = out2.plot(annualize="D") #generating volatility graphs

# Estimating TGARCH

model3= arch_model(returns, p=1, o=1, q=1, power=1.0)
out3= model3.fit()
print(out3.summary())
fig3 = out3.plot(annualize="D") #generating volatility graphs
# Out:
# Iteration:      1,   Func. Count:      5,   Neg. LLF: 9321.046574932674
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 2762.7816219790866
# Iteration:      3,   Func. Count:     21,   Neg. LLF: 1446.2499776163816
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 1365.6360829182436
# Iteration:      5,   Func. Count:     32,   Neg. LLF: 1360.243155807946
# Iteration:      6,   Func. Count:     36,   Neg. LLF: 1360.2414774117715
# Iteration:      7,   Func. Count:     40,   Neg. LLF: 1360.2414742195267
# Iteration:      8,   Func. Count:     43,   Neg. LLF: 1360.2414742196374
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1360.2414742195267
#             Iterations: 8
#             Function evaluations: 43
#             Gradient evaluations: 8
#                       Constant Mean - ARCH Model Results
# ...
# Dep. Variable:              Adj Close   R-squared:                       0.000
# ...
